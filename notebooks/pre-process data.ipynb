# %%
from data_utils import *
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
process = ProcessData()

# %%
process.read_data()
print("\nBefore Pre-processing:")
process.verify_preprocess()
# Out:
# Memory Usage:  2017.10 MB
# Number of records and columns:  (8738120, 9)
# event_time        object
# event_type        object
# product_id         int64
# category_id        int64
# category_code     object
# brand             object
# price            float64
# user_id            int64
# user_session      object
# dtype: object
# Null %:  98.79565627388958
#
#  Before Pre-processing:
# duplicates : fail
# price : fail
# event_time : fail
# user_session : fail

# %%
process.optimized_read()
print("\nBefore Pre-processing (optimized data):")
process.verify_preprocess()
# Out:
# Memory Usage:  1262.29 MB
# Number of records and columns:  (8738120, 9)
# event_time       datetime64[ns]
# event_type             category
# product_id               uint32
# category_id              uint64
# category_code            object
# brand                    object
# price                   float32
# user_id                  uint32
# user_session             object
# dtype: object
# Null %:  98.79565627388958
#
# Before Pre-processing (optimized data):
# price : fail
# user_session : fail
# duplicates : fail
# event_time : success

# %%
process.pre_process()
print("\nAfter Pre-processing:")
process.verify_preprocess()
# Out:
# /usr/local/lib/python3.5/dist-packages/pandas/core/computation/check.py:17: UserWarning: The installed version of numexpr 2.4.3 is not supported in pandas and will be not be used
# The minimum supported version is 2.4.6
#
#   ver=ver, min_ver=_MIN_NUMEXPR_VERSION), UserWarning)
# After pre-processing:
# Memory Usage:  805.02 MB
# Number of records and columns:  (8275749, 7)
# event_time      datetime64[ns]
# event_type            category
# product_id              uint32
# category_id             uint64
# price                  float32
# user_id                 uint32
# user_session            object
# dtype: object
# Null %:  0.0
#
# After Pre-processing:
# price : success
# user_session : success
# duplicates : success
# event_time : success

# %%
process.filter_products()
# Out:
# After filtering products:
# Memory Usage:  188.35 MB
# Number of records and columns:  (1936262, 7)
# event_time      datetime64[ns]
# event_type            category
# product_id              uint32
# category_id             uint64
# price                  float32
# user_id                 uint32
# user_session            object
# dtype: object
# Null %:  0.0

# %%
print(process.df.shape)
print(process.filtered_df.shape)
# Out:
# (8275749, 7)
# (1936262, 7)
